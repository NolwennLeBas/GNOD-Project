# %% [markdown]
#                                 Expanding the collection of songs and adding audio features

# %%
import pandas as pd
from pandas import json_normalize

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from random import randint
from time import sleep

# %%
pd.set_option("display.max_columns", 0)

# %% [markdown]
# * Connecting to Spotify

# %%
secrets_file = open(".secret.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# * Getting top 10 000 songs playlist

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("3BsxEMRSmNfSx6etRrg06y")
len(all_tracks)
# Out:
# 9866

# %%
tracks = json_normalize(all_tracks)
tracks

# %% [markdown]
# * Extracting all the artists for each songs

# %%
artists_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks.index:
    artists_for_song = json_normalize(tracks.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks.iloc[i]['track.popularity'] # same for popularity   
    artists_df = pd.concat([artists_df, artists_for_song], axis=0)

# %%
artists_df.head()
# Out:
#                                                 href  ... popularity
# 0  https://api.spotify.com/v1/artists/2uH0RyPcX7f...  ...         52
# 0  https://api.spotify.com/v1/artists/7v4imS0moSy...  ...         58
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  ...          0
# 0  https://api.spotify.com/v1/artists/6aq8T2Rcspx...  ...          0
# 0  https://api.spotify.com/v1/artists/4E9w0bms6Hc...  ...         10
#
# [5 rows x 9 columns]

# %%
df_final = artists_df[['song_name', 'name', 'song_id', 'popularity']].reset_index(drop=True)
df_final
# Out:
#                                                song_name  ... popularity
# 0                         A Design for Life - Remastered  ...         52
# 1                                             Nature Boy  ...         58
# 2                    Bohemian Rhapsody - Remastered 2011  ...          0
# 3                                           Tainted Love  ...          0
# 4                                      Ode To Billie Joe  ...         10
# ...                                                  ...  ...        ...
# 11519  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11520  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11521  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11522  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11523  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
#
# [11524 rows x 4 columns]

# %%
df_final.isna().sum()
#we have to drop the rows with null values in song_id since we won't be able to extract song features for them
# Out:
# song_name      0
# name           0
# song_id       39
# popularity     0
# dtype: int64

# %%
df_final2=df_final.dropna()
df_final2
# Out:
#                                                song_name  ... popularity
# 0                         A Design for Life - Remastered  ...         52
# 1                                             Nature Boy  ...         58
# 2                    Bohemian Rhapsody - Remastered 2011  ...          0
# 3                                           Tainted Love  ...          0
# 4                                      Ode To Billie Joe  ...         10
# ...                                                  ...  ...        ...
# 11519  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11520  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11521  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11522  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
# 11523  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...         49
#
# [11485 rows x 4 columns]

# %% [markdown]
# * Getting audio features for each song_id

# %%
chunks = [(i, i+100) for i in range(0, len(df_final2), 100)]
chunks  #produces a list of tuples
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final2['song_id'][chunk[0]:chunk[1]]   #chunk[0]= first number of the tuple, chunk[1]= second number
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)

# %%
audio_features_df = json_normalize(audio_features_list)
audio_features_df
# Out:
#        danceability  energy  ...  duration_ms  time_signature
# 0             0.184  0.8410  ...     257640.0             4.0
# 1             0.275  0.0895  ...     173533.0             4.0
# 2             0.414  0.4040  ...     354320.0             4.0
# 3             0.518  0.5100  ...     153880.0             4.0
# 4             0.595  0.1820  ...     254600.0             4.0
# ...             ...     ...  ...          ...             ...
# 11480         0.000  0.0170  ...      63800.0             0.0
# 11481         0.000  0.0170  ...      63800.0             0.0
# 11482         0.000  0.0170  ...      63800.0             0.0
# 11483         0.000  0.0170  ...      63800.0             0.0
# 11484         0.000  0.0170  ...      63800.0             0.0
#
# [11485 rows x 18 columns]

# %%
audio_features_df.drop_duplicates(inplace=True) # duplicates because some songs have more artists
audio_features_df.shape
# Out:
# (9958, 18)

# %% [markdown]
# * Concatenating the songs with their audio features and exporting the df in a csv file

# %%
df_w_audio_ft = pd.merge(left=df_final2, right=audio_features_df, how='inner', left_on='song_id',right_on='id')
df_w_audio_ft
# Out:
#                                                song_name  ... time_signature
# 0                         A Design for Life - Remastered  ...            4.0
# 1                                             Nature Boy  ...            4.0
# 2                    Bohemian Rhapsody - Remastered 2011  ...            4.0
# 3                                           Tainted Love  ...            4.0
# 4                                      Ode To Billie Joe  ...            4.0
# ...                                                  ...  ...            ...
# 11477  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...            0.0
# 11478  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...            0.0
# 11479  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...            0.0
# 11480  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...            0.0
# 11481  Pelleas et Melisande, Op. 80 (arr. C. Koechlin...  ...            0.0
#
# [11482 rows x 22 columns]

# %%
#df_w_audio_ft.to_csv('top_10000_songs.csv', index=False)
